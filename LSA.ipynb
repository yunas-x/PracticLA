# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd

# %%
df = pd.read_excel("gdrive/MyDrive/Colab Notebooks/DataLSA.xlsx")

# %%
df2 = pd.read_excel("gdrive/MyDrive/Colab Notebooks/DataLSA2.xlsx")

# %%
docs = df[:3]
words = df[3:]

# %%
docs2 = df2[:3]
words2 = df2[3:]

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots()
ax.scatter(docs.S1, docs.S2, s = 60, marker="*")
ax.scatter(words.S1, words.S2)

for i, txt in enumerate(docs.Name):
    ax.annotate(txt, (docs.S1[i], docs.S2[i]))

#for i, txt in enumerate(words.Name):
#    ax.annotate(txt, (words.S1[len(docs.Name) + i], words.S2[len(docs.Name) + i]))

# %%
fig, ax = plt.subplots()

ax.scatter(docs2.S1, docs2.S2, s = 60, marker="*")
ax.scatter(words2.S1, words2.S2)
#ax.plot([0, 0.63], linestyle = 'dotted')
#ax.plot([0, 0.68], linestyle = 'dotted')
ax.scatter(0.264, 0.265, marker="s")

for i, txt in enumerate(docs2.Name):
    ax.annotate(txt, (docs2.S1[i], docs2.S2[i]))

for i, txt in enumerate(words2.Name):
    ax.annotate(txt, (words2.S1[len(docs2.Name) + i], words2.S2[len(docs2.Name) + i]))
